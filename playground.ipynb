# %% [markdown]
# # Experiment to compaire model anf forecast uncertainty of simple and complex models

# %%
import prosper_nn as pnn
from prosper_nn.models.hcnn import HCNN
from prosper_nn.models.ensemble import Ensemble
import prosper_nn.utils.generate_time_series_data as gtsd
import prosper_nn.utils.neuron_correlation_hidden_layers as nchl
import prosper_nn.utils.create_input_ecnn_hcnn as ci
import prosper_nn.utils.visualization as visualization
from prosper_nn.utils import visualize_forecasts
from prosper_nn.utils import sensitivity_analysis
import torch
from tqdm import trange
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.figsize'] = (10,14)
# torch.set_default_dtype(torch.float32)
# torch.set_default_device('cuda')

# %% [markdown]
# ### Basic settings

# %%
past_horizon = 40
forecast_horizon = 40
batchsize = 8
n_data = 200

# %% [markdown]
# ### First Experiment (Sinwave as a simple and fully deterministic data generating process)

# %%
omega = 0.2
data = (torch.sin(torch.arange(0, n_data*omega, omega)) + 1) / 2 # sin(omega * x) and normalize to [0,1]
plt.plot(data.cpu().numpy())
plt.show()
print(data.shape)

Y = data.unsqueeze(1)
print(Y.shape)
Y_batches = ci.create_input(
    Y=Y,
    past_horizon=past_horizon,
    batchsize=batchsize,
    forecast_horizon=forecast_horizon,
)
Y_batches.shape
# Out:
# torch.Size([200])
# torch.Size([200, 1])
# C:\Users\Max\AppData\Local\Temp\ipykernel_20252\472164575.py:9: UserWarning: The number of sequences generated from the data are not a multiple of batchsize. The first 1 sequences will be discarded.
#   Y_batches = ci.create_input(
# torch.Size([20, 40, 8, 1])

# %%
n_features_Y=1
n_state_neurons = 50
sparsity = 0
n_models = 100
lstm = False

small_hcnn_model = HCNN(
    n_state_neurons=n_state_neurons,
    n_features_Y=n_features_Y,
    past_horizon=past_horizon,
    forecast_horizon=forecast_horizon,
    sparsity=sparsity,
    lstm=lstm,
)
small_hcnn_ensemble = Ensemble(
    model=small_hcnn_model, n_models=n_models, sparsity=sparsity, combination_type="mean"
)

targets = torch.zeros((past_horizon, batchsize, n_features_Y))
optimizer = torch.optim.Adam(small_hcnn_ensemble.parameters(), lr=0.001)
loss_function = torch.nn.MSELoss()

# %%
epochs = 50
small_hcnn_ensemble.train()
total_loss = epochs * [0]
with trange(epochs, desc="Model Training", unit="epoch") as tepoch:
    for epoch in tepoch:
        for batch_index in range(0, Y_batches.shape[0]):
            small_hcnn_ensemble.zero_grad()

            Y_batch = Y_batches[batch_index]
            ensemble_output = small_hcnn_ensemble(Y_batch)
            outputs, mean = torch.split(ensemble_output, n_models)
            mean = torch.squeeze(mean, 0)
            past_errors, forecasts = torch.split(outputs, past_horizon, dim=1)

            losses = [
                loss_function(past_errors[j][i], targets[i])
                for j in range(n_models)
                for i in range(past_horizon)
            ]
            loss = sum(losses) / (n_models * past_horizon)
            loss.backward()

            optimizer.step()

            mean_loss = (
                sum([loss_function(mean[i], targets[i]) for i in range(past_horizon)])
                / past_horizon
            )
            total_loss[epoch] += mean_loss.detach()
        tepoch.set_postfix(loss=loss.item())
# Out:
# Model Training: 100%|██████████| 50/50 [28:10<00:00, 33.82s/epoch, loss=0.00515]

# %%
torch.save(small_hcnn_ensemble, f"small_hcnn_ensemble_{n_models}.pt")

# %%
Y[:past_horizon+ forecast_horizon].shape
# Out:
# torch.Size([80, 1])

# %%
n_models = 100
small_hcnn_ensemble = torch.load(f"small_hcnn_ensemble_{n_models}.pt")

# %%
test_batch =Y[:past_horizon + forecast_horizon].unsqueeze(1)
print(test_batch.shape)
with torch.no_grad():
    small_hcnn_ensemble.eval()

    output_forecast = small_hcnn_ensemble(test_batch[:past_horizon])
    forecasts = output_forecast[0, past_horizon:]
# Out:
# torch.Size([80, 1, 1])

# %%
expected_timeseries = torch.cat(
    (torch.add(output_forecast[-1, :past_horizon], test_batch[:past_horizon]), output_forecast[-1, past_horizon:]),
    dim=0,
).detach()
expected_timeseries_outputs = torch.cat(
    (torch.add(output_forecast[:-1, :past_horizon], test_batch[:past_horizon]), output_forecast[:-1, past_horizon:]), dim=1
).detach()

visualize_forecasts.plot_time_series(
    expected_time_series=expected_timeseries[:, 0, 0],
    target=test_batch[:, 0, 0],
    uncertainty=expected_timeseries_outputs[:, :, 0, 0].T,
)

# %%
# mpl.rcParams['figure.figsize'] = (16,7)
# from torch.nn.functional import interpolate
fig = visualize_forecasts.heatmap_forecasts(expected_timeseries_outputs[:, past_horizon:, 0, 0].T, figsize=(12,10))
# plt.plot(interpolate(expected_timeseries.transpose(0,2), 15*(forecast_horizon-1), mode="linear")[0, 0, :], color="red", label="Expected")
# plt.plot(interpolate(test_batch.transpose(0,2), 15*(forecast_horizon-1), mode="linear")[0, 0, :], color="black", linestyle="--", label="Target")
# plt.legend()
plt.show()

# %%
expected_timeseries_outputs[:-1, :, 0, 0].shape
# Out:
# torch.Size([99, 80])

# %%
test_batch =Y[:past_horizon + forecast_horizon].unsqueeze(1)
vars = []
for n_model in [10, 50, 100]:
    model = torch.load(f"small_hcnn_ensemble_{n_model}.pt")
    with torch.no_grad():
        model.eval()

        output_forecast = model(test_batch[:past_horizon])
        forecasts = output_forecast[0, past_horizon:]
    
    expected_timeseries = torch.cat(
        (torch.add(output_forecast[-1, :past_horizon], test_batch[:past_horizon]), output_forecast[-1, past_horizon:]),
        dim=0,
        ).detach()
    expected_timeseries_outputs = torch.cat(
        (torch.add(output_forecast[:-1, :past_horizon], test_batch[:past_horizon]), output_forecast[:-1, past_horizon:]), dim=1
    ).detach()
    fig = visualize_forecasts.heatmap_forecasts(expected_timeseries_outputs[:, past_horizon:, 0, 0].T, figsize=(12,10))
    plt.show()

# %%
test_batch =Y[:past_horizon + forecast_horizon].unsqueeze(1)
vars = []
fig = plt.figure(figsize=(16,8))
for n_model in [10, 50, 100]:
    model = torch.load(f"small_hcnn_ensemble_{n_model}.pt")
    with torch.no_grad():
        model.eval()

        output_forecast = model(test_batch[:past_horizon])
        forecasts = output_forecast[0, past_horizon:]
    
    expected_timeseries = torch.cat(
        (torch.add(output_forecast[-1, :past_horizon], test_batch[:past_horizon]), output_forecast[-1, past_horizon:]),
        dim=0,
        ).detach()
    expected_timeseries_outputs = torch.cat(
        (torch.add(output_forecast[:-1, :past_horizon], test_batch[:past_horizon]), output_forecast[:-1, past_horizon:]), dim=1
    ).detach()
    var = np.sqrt(np.var(expected_timeseries_outputs[:, :, 0, 0].numpy(), axis=0))
    vars.append(var)
    plt.plot(var[past_horizon:], label=f"{n_model} models")
plt.xlabel("Forecast Horizon")
plt.ylabel("Standard Deviation")
plt.legend()
plt.show()

# %%
import pandas as pd
var_Df = pd.DataFrame(vars, columns=[f"t+{i}" for i in range(1, forecast_horizon+1)], index=[f"{n_model} models" for n_model in [10, 50, 100]])

# %%
from scipy.io.arff import loadarff
train_arff = loadarff("ECG5000_TRAIN.arff")
test_arff = loadarff("ECG5000_TEST.arff")

# %%
train_data = []
for i in range(len(train_arff[0])):
    signal = np.array([x for x in train_arff[0][i].tolist() if type(x) == float])
    train_data.append(signal)
train_data = np.concatenate(train_data)
test_data = []
for i in range(len(test_arff[0])):
    signal = np.array([x for x in test_arff[0][i].tolist() if type(x) == float])
    test_data.append(signal)
test_data = np.concatenate(test_data)

# %%
from sklearn.preprocessing import MinMaxScaler
from scipy.signal import decimate
scaler = MinMaxScaler()
train_data = decimate(scaler.fit_transform(train_data.reshape(-1, 1)).reshape(-1), 5)
print(train_data.shape)
Y = torch.from_numpy(train_data)
print(Y.shape)
plt.plot(train_data)
# plt.vlines(range(140, 1000, 140), ymin=0, ymax=1, color="red", linestyle="--")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 4
#       2 from scipy.signal import decimate
#       3 scaler = MinMaxScaler()
# ----> 4 train_data = decimate(scaler.fit_transform(train_data.reshape(-1, 1)).reshape(-1), 5)
#       5 print(train_data.shape)
#       6 Y = torch.from_numpy(train_data)
#
# File c:\Users\Max\miniconda3\envs\Prosper\lib\site-packages\scipy\signal\_signaltools.py:4560, in decimate(x, q, n, ftype, axis, zero_phase)
#    4558 else:  # IIR case
#    4559     if zero_phase:
# -> 4560         y = sosfiltfilt(sos, x, axis=axis)
#    4561     else:
#    4562         y = sosfilt(sos, x, axis=axis)
#
# File c:\Users\Max\miniconda3\envs\Prosper\lib\site-packages\scipy\signal\_signaltools.py:4411, in sosfiltfilt(sos, x, axis, padtype, padlen)
#    4409 ntaps = 2 * n_sections + 1
#    4410 ntaps -= min((sos[:, 2] == 0).sum(), (sos[:, 5] == 0).sum())
# -> 4411 edge, ext = _validate_pad(padtype, padlen, x, axis,
#    4412                           ntaps=ntaps)
#    4414 # These steps follow the same form as filtfilt with modifications
#    4415 zi = sosfilt_zi(sos)  # shape (n_sections, 2) --> (n_sections, ..., 2, ...)
#
# File c:\Users\Max\miniconda3\envs\Prosper\lib\site-packages\scipy\signal\_signaltools.py:4180, in _validate_pad(padtype, padlen, x, axis, ntaps)
#    4178 # x's 'axis' dimension must be bigger than edge.
#    4179 if x.shape[axis] <= edge:
# -> 4180     raise ValueError("The length of the input vector x must be greater "
#    4181                      "than padlen, which is %d." % edge)
#    4183 if padtype is not None and edge > 0:
#    4184     # Make an extension of length `edge` at each
#    4185     # end of the input array.
#    4186     if padtype == 'even':
#
# ValueError: The length of the input vector x must be greater than padlen, which is 27.

# %%
n_state_neurons = 20
past_horizon=200
forecast_horizon=200
n_features_Y = 1
sparsity = 0.1
n_models = 50
lstm = False
torch.set_default_dtype(torch.float64)

Y_batches = ci.create_input(
    Y=train_data.unsqueeze(1),
    past_horizon=past_horizon,
    batchsize=batchsize,
    forecast_horizon=forecast_horizon,
)
print(Y_batches.dtype, Y_batches.shape)


larger_hcnn_model = HCNN(
    n_state_neurons=n_state_neurons,
    n_features_Y=n_features_Y,
    past_horizon=past_horizon,
    forecast_horizon=forecast_horizon,
    sparsity=sparsity,
    lstm=lstm,
)
larger_hcnn_ensemble = Ensemble(
    model=larger_hcnn_model, n_models=n_models, sparsity=sparsity, combination_type="mean"
)

targets = torch.zeros((past_horizon, batchsize, n_features_Y), dtype=torch.float64)
optimizer = torch.optim.Adam(larger_hcnn_ensemble.parameters(), lr=0.001)
loss_function = torch.nn.MSELoss()
# Out:
# torch.float64 torch.Size([50, 200, 16, 1])
# C:\Users\Max\AppData\Local\Temp\ipykernel_3000\2309832031.py:10: UserWarning: The number of sequences generated from the data are not a multiple of batchsize. The first 1 sequences will be discarded.
#   Y_batches = ci.create_input(

# %%
epochs = 200
larger_hcnn_ensemble.train()
total_loss = epochs * [0]
with trange(epochs, desc="Model Training", unit="epoch") as tepoch:
    for epoch in tepoch:
        for batch_index in range(0, Y_batches.shape[0]):
            larger_hcnn_ensemble.zero_grad()

            Y_batch = Y_batches[batch_index]
            ensemble_output = larger_hcnn_ensemble(Y_batch)
            outputs, mean = torch.split(ensemble_output, n_models)
            mean = torch.squeeze(mean, 0)
            past_errors, forecasts = torch.split(outputs, past_horizon, dim=1)

            losses = [
                loss_function(past_errors[j][i], targets[i])
                for j in range(n_models)
                for i in range(past_horizon)
            ]
            loss = sum(losses) / (n_models * past_horizon)
            loss.backward()

            optimizer.step()

            mean_loss = (
                sum([loss_function(mean[i], targets[i]) for i in range(past_horizon)])
                / past_horizon
            )
            total_loss[epoch] += mean_loss.detach()
        tepoch.set_postfix(loss=loss.item())
# Out:
# Model Training:   2%|▏         | 4/200 [43:40<35:39:44, 655.03s/epoch, loss=0.0162]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 15
#      12 mean = torch.squeeze(mean, 0)
#      13 past_errors, forecasts = torch.split(outputs, past_horizon, dim=1)
# ---> 15 losses = [
#      16     loss_function(past_errors[j][i], targets[i])
#      17     for j in range(n_models)
#      18     for i in range(past_horizon)
#      19 ]
#      20 loss = sum(losses) / (n_models * past_horizon)
#      21 loss.backward()
#
# Cell In[26], line 16, in <listcomp>(.0)
#      12 mean = torch.squeeze(mean, 0)
#      13 past_errors, forecasts = torch.split(outputs, past_horizon, dim=1)
#      15 losses = [
# ---> 16     loss_function(past_errors[j][i], targets[i])
#      17     for j in range(n_models)
#      18     for i in range(past_horizon)
#      19 ]
#      20 loss = sum(losses) / (n_models * past_horizon)
#      21 loss.backward()
#
# File c:\Users\Max\miniconda3\envs\Prosper\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Max\miniconda3\envs\Prosper\lib\site-packages\torch\nn\modules\loss.py:536, in MSELoss.forward(self, input, target)
#     535 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 536     return F.mse_loss(input, target, reduction=self.reduction)
#
# File c:\Users\Max\miniconda3\envs\Prosper\lib\site-packages\torch\nn\functional.py:3295, in mse_loss(input, target, size_average, reduce, reduction)
#    3292     reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3294 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 3295 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# KeyboardInterrupt:

# %%
forecast_horizon=100
random_index = np.random.randint(0, Y.shape[0]-past_horizon-forecast_horizon)

test_batch =Y[random_index:random_index + past_horizon + forecast_horizon].unsqueeze(1)
print(test_batch.shape)
with torch.no_grad():
    larger_hcnn_ensemble.eval()
    output_forecast = larger_hcnn_ensemble(test_batch[:past_horizon])
    forecasts = output_forecast[0, past_horizon:]
# Out:
# torch.Size([300, 1, 1])

# %%
expected_timeseries = torch.cat(
    (torch.add(output_forecast[-1, :past_horizon], test_batch[:past_horizon]), output_forecast[-1, past_horizon:]),
    dim=0,
).detach()
expected_timeseries_outputs = torch.cat(
    (torch.add(output_forecast[:-1, :past_horizon], test_batch[:past_horizon]), output_forecast[:-1, past_horizon:]), dim=1
).detach()

visualize_forecasts.plot_time_series(
    expected_time_series=expected_timeseries[:, 0, 0],
    target=test_batch[:, 0, 0],
    uncertainty=expected_timeseries_outputs[:, :, 0, 0].T,
)

# %%
torch.save(larger_hcnn_ensemble, f"larger_hcnn_ensemble_{n_models}.pt")

# %%
# mpl.rcParams['figure.figsize'] = (16,7)
# from torch.nn.functional import interpolate
fig = visualize_forecasts.heatmap_forecasts(expected_timeseries_outputs[:, past_horizon:, 0, 0].T, figsize=(16, 7))
# plt.xticks(mpl.ticker.MultipleLocator(20))
# plt.plot(interpolate(expected_timeseries.transpose(0,2), 15*(forecast_horizon-1), mode="linear")[0, 0, :], color="red", label="Expected")
# plt.plot(interpolate(test_batch.transpose(0,2), 15*(forecast_horizon-1), mode="linear")[0, 0, :], color="black", linestyle="--", label="Target")
# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 3
#       1 # mpl.rcParams['figure.figsize'] = (16,7)
#       2 # from torch.nn.functional import interpolate
# ----> 3 fig = visualize_forecasts.heatmap_forecasts(expected_timeseries_outputs[:, past_horizon:, 0, 0].T, figsize=(16, 7))
#       4 # plt.xticks(mpl.ticker.MultipleLocator(20))
#       5 # plt.plot(interpolate(expected_timeseries.transpose(0,2), 15*(forecast_horizon-1), mode="linear")[0, 0, :], color="red", label="Expected")
#       6 # plt.plot(interpolate(test_batch.transpose(0,2), 15*(forecast_horizon-1), mode="linear")[0, 0, :], color="black", linestyle="--", label="Target")
#       7 # plt.legend()
#       8 plt.show()
#
# File c:\Users\Max\Repositories\prosper_nn\prosper_nn\utils\visualize_forecasts.py:291, in heatmap_forecasts(forecasts, sigma, num_interp, window_height, batch_first, save_at, xlabel, ylabel, title, figsize)
#     289 window_width = num_interp * (forecasts.shape[1] - 1)
#     290 interpolated_forecasts = _interpolate_forecasts(forecasts, window_width)
# --> 291 heatmap_matrix = _calculate_heatmap_matrix(
#     292     interpolated_forecasts, sigma, window_width, window_height
#     293 )
#     294 heatmap_matrix = torch.div(heatmap_matrix, heatmap_matrix.max(axis=0)[0])
#     295 yticks = {
#     296     "ticks": range(0, window_height + 1, 10),
#     297     "labels": [
#    (...)
#     300     ],
#     301 }
#
# File c:\Users\Max\Repositories\prosper_nn\prosper_nn\utils\visualize_forecasts.py:231, in _calculate_heatmap_matrix(interpolated_forecasts, sigma, window_width, window_height)
#     226     for y_index in range(window_height):
#     227         forecasts_at_x_index = [
#     228             forecast[x_index] for forecast in interpolated_forecasts
#     229         ]
#     230         heat = sum(
# --> 231             [
#     232                 _gaussian(y_forecast, y_positions[y_index], sigma)
#     233                 for y_forecast in forecasts_at_x_index
#     234             ]
#     235         )
#     236         heatmap[window_height - (y_index + 1)][x_index] = heat
#     237 return heatmap
#
# File c:\Users\Max\Repositories\prosper_nn\prosper_nn\utils\visualize_forecasts.py:232, in <listcomp>(.0)
#     226     for y_index in range(window_height):
#     227         forecasts_at_x_index = [
#     228             forecast[x_index] for forecast in interpolated_forecasts
#     229         ]
#     230         heat = sum(
#     231             [
# --> 232                 _gaussian(y_forecast, y_positions[y_index], sigma)
#     233                 for y_forecast in forecasts_at_x_index
#     234             ]
#     235         )
#     236         heatmap[window_height - (y_index + 1)][x_index] = heat
#     237 return heatmap
#
# File c:\Users\Max\Repositories\prosper_nn\prosper_nn\utils\visualize_forecasts.py:152, in _gaussian(x, mean, sigma)
#     134 def _gaussian(x: torch.Tensor, mean: torch.Tensor, sigma: float) -> float:
#     135     """
#     136     Calculates the result of the gaussian function.
#     137
#    (...)
#     150         Output of the gaussian function for a given input.
#     151     """
# --> 152     return torch.exp(-torch.pow((x - mean) / sigma, 2.0))
#
# KeyboardInterrupt:

# %%
data_generating_model = HCNN(
    n_state_neurons=n_state_neurons,
    n_features_Y=n_features_Y,
    past_horizon=past_horizon,
    forecast_horizon=forecast_horizon,
    sparsity=sparsity,
)

# %%
optimizer = torch.optim.Adam(data_generating_model.parameters(), lr=0.001)
loss_function = torch.nn.MSELoss()

# %%
targets = torch.zeros((past_horizon, batchsize, n_features_Y))

# %%
Y_batches[0, :, 0].unsqueeze(1).shape
# Out:
# torch.Size([30, 1, 2])

# %%
with torch.no_grad():
    data_generating_model.eval()
    input = Y_batches[0, :, 0].unsqueeze(1)
    print(input)
    print(input.shape)
    output_forecast = data_generating_model(Y_batches[0, :, 0].unsqueeze(1))
    print(output_forecast.shape)
    forecast = output_forecast[-1, past_horizon:]
# Out:
# tensor([[[ 1.0072,  0.9795]],
#
#         [[ 1.6733,  0.8716]],
#
#         [[ 1.2485,  0.4338]],
#
#         [[ 0.4618,  0.2912]],
#
#         [[ 0.0631,  0.2123]],
#
#         [[ 0.0744,  0.0948]],
#
#         [[ 1.1101,  0.9562]],
#
#         [[ 0.2243,  0.4533]],
#
#         [[ 0.0908,  0.8648]],
#
#         [[-0.2845,  0.4879]],
#
#         [[ 0.8784,  0.8971]],
#
#         [[ 1.7271,  0.9391]],
#
#         [[ 0.9963,  0.2396]],
#
#         [[ 0.5650,  0.3424]],
#
#         [[ 0.2504,  0.3399]]])
# torch.Size([15, 1, 2])
# torch.Size([30, 1, 2])

# %%
def generate_data_from_hcnn(model, init_state, n_data, stepsize=2):
    new_data = []
    current_state = init_state
    for i in range(n_data):
        forcast = model(current_state)[-1, past_horizon:past_horizon + stepsize]
        new_data.append(forcast)
        current_state = torch.cat((current_state[:, 1:], new_state), 1)

# %%
expected_timeseries = torch.cat(
    (torch.add(past_error.squeeze(), Y[:past_horizon]), forecast.squeeze()), dim=0
).detach()

visualize_forecasts.plot_time_series(
    expected_time_series=expected_timeseries[:, 0],
    target=Y[: past_horizon + forecast_horizon, 0],
)

# %%
with torch.no_grad():
    states_for_correlation = torch.empty(
        (Y_batches.shape[0], batchsize, n_state_neurons)
    )

    for batch_index in range(0, Y_batches.shape[0]):
        Y_batch = Y_batches[batch_index]
        model_output = hcnn_model(Y_batch)
        states_for_correlation[batch_index] = hcnn_model.state[past_horizon]
    states_for_correlation = states_for_correlation.reshape((-1, n_state_neurons))

    corr_matrix, max_corr, ind_neurons = nchl.hl_size_analysis(states_for_correlation)
# Out:
# The most correlated neurons are the ones with indices  [3, 0]
# The according Pearson correlation coefficient is -0.85

# %%
hcnn_model.state[0].shape
# Out:
# torch.Size([1, 5])

# %%
hcnn_ensemble = Ensemble(
    model=hcnn_model, n_models=n_models, sparsity=sparsity, combination_type="median"
)

# %% [markdown]
# ### Build a deterministic timeseries generator
# We use a HCNN as our data generating process:
# - Trained on synthetic data to get a resonable HCNN state
# - To ensure that the variation of the produced time series cannot also be explained by a less complex model, the state size is chosen in such a way that there is only a low redundancy/correlation between the individual neurons (target value: max. 0.7).
#
#
# + vary the complexity by changing the size of the state matrix
# + for a given init state the process is fully deterministic
#
# &rarr; No Forcast Uncertainty
